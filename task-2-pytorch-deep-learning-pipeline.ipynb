# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU count: 2
# GPU name: Tesla T4

# %%
# !git clone https://github.com/Jisan10667/pytorch-pipeline-Jisan.git
# %cd pytorch-pipeline-Jisan
# Out:
# Cloning into 'pytorch-pipeline-Jisan'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 30 (delta 0), reused 30 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 21.67 KiB | 3.61 MiB/s, done.
# /kaggle/working/pytorch-pipeline-Jisan

# %%
# !pip install -q datasets tensorboard pytest-cov

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/prepare_food101_subset.py \
  --dataset ethz/food101 \
  --output-dir data/pizza_steak_sushi \
  --classes pizza steak sushi \
  --images-per-class 225
# Out:
# ...
# README.md: 16.4kB [00:00, 27.3MB/s]
# data/train-00000-of-00008.parquet:  41%|██   | 201M/490M [00:02<00:03, 82.3MB/s]
# data/train-00001-of-00008.parquet:  43%|██▌   | 201M/464M [00:01<00:02, 101MB/s]
# data/train-00002-of-00008.parquet:  71%|████▎ | 335M/472M [00:02<00:00, 162MB/s]
# data/train-00003-of-00008.parquet:  93%|█████▌| 431M/464M [00:02<00:00, 200MB/s]
# data/train-00004-of-00008.parquet:  42%|██   | 201M/475M [00:02<00:02, 97.3MB/s]
# data/train-00005-of-00008.parquet:  57%|███▍  | 268M/470M [00:02<00:01, 123MB/s]
# data/train-00006-of-00008.parquet:  79%|████▊ | 379M/478M [00:02<00:00, 169MB/s]
# data/train-00007-of-00008.parquet:  55%|███▎  | 268M/486M [00:02<00:01, 122MB/s]
# data/validation-00000-of-00003.parquet:  48%|▍| 201M/423M [00:02<00:02, 84.3MB/s
# data/validation-00001-of-00003.parquet:  85%|▊| 350M/413M [00:02<00:00, 152MB/s]
# data/validation-00002-of-00003.parquet:  32%|▎| 134M/426M [00:02<00:04, 61.2MB/s
# ...

# %%
# !find data/pizza_steak_sushi -maxdepth 2 -type f | wc -l
# !find data/pizza_steak_sushi -maxdepth 1 -type d
# Out:
# 675
# data/pizza_steak_sushi
# data/pizza_steak_sushi/sushi
# data/pizza_steak_sushi/steak
# data/pizza_steak_sushi/pizza

# %% [markdown]
# **Train TinyVGG**

# %%
# !python train.py --data-dir data/pizza_steak_sushi --epochs 5 --lr 0.001
# Out:
# 2026-05-09 06:04:03.471096: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778306643.877886     717 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778306644.038096     717 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778306645.281519     717 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **run the full TinyVGG training:**

# %%
# !python train.py --data-dir data/pizza_steak_sushi --epochs 30 --lr 0.001
# Out:
# 2026-05-09 06:05:22.375660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778306722.398742     747 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778306722.406399     747 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778306722.427078     747 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py --data-dir data/pizza_steak_sushi --epochs 30 --lr 0.001 --hidden-units 20
# Out:
# 2026-05-09 06:06:43.681682: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778306803.704378     777 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778306803.711741     777 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778306803.731106     777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py --data-dir data/pizza_steak_sushi --epochs 30 --compare-grid
# Out:
# 2026-05-09 06:11:46.674431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778307106.696703     849 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778307106.704156     849 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778307106.724454     849 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **EfficientNet:**

# %%
# !python train.py --data-dir data/pizza_steak_sushi --model effnetb0 --epochs 10 --lr 0.001
# Out:
# 2026-05-09 06:15:26.058501: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778307326.088616     889 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778307326.096031     889 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778307326.115852     889 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r kaggle_training_outputs.zip models experiments loss_curves.png experiment_comparison.png
# Out:
# updating: models/ (stored 0%)
# updating: models/best_model.pth (deflated 8%)
# updating: models/.gitkeep (stored 0%)
# updating: experiments/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/summary.json (deflated 44%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/lr_0.001_hidden_20/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/lr_0.001_hidden_20/Accuracy_test/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/lr_0.001_hidden_20/Accuracy_test/events.out.tfevents.1778306812.43b1253882f0.777.4 (deflated 56%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/lr_0.001_hidden_20/Loss_test/ (stored 0%)
# updating: experiments/tinyvgg-20260509-060649/tinyvgg/lr_0.001_hidden_20/Loss_test/events.out.tfevents.1778306812.43b1253882f0.777.2 (deflated 52%)
# ...
